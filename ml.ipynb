# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style('whitegrid')
import statsmodels.api as sm

# %%
raw_data = pd.read_csv('admitance.csv')

# %%
raw_data.head()
# Out:
#     SAT Admitted
# 0  1363       No
# 1  1792      Yes
# 2  1954      Yes
# 3  1653       No
# 4  1593       No

# %%
data = raw_data.copy()

# %%
data
# Out:
#       SAT Admitted
# 0    1363       No
# 1    1792      Yes
# 2    1954      Yes
# 3    1653       No
# 4    1593       No
# ..    ...      ...
# 163  1722      Yes
# 164  1750      Yes
# 165  1555       No
# 166  1524       No
# 167  1461       No
#
# [168 rows x 2 columns]

# %%
data['Admitted'] = data['Admitted'].map({'yes':1,'No':0})

# %%
data
# Out:
#       SAT  Admitted
# 0    1363       0.0
# 1    1792       NaN
# 2    1954       NaN
# 3    1653       0.0
# 4    1593       0.0
# ..    ...       ...
# 163  1722       NaN
# 164  1750       NaN
# 165  1555       0.0
# 166  1524       0.0
# 167  1461       0.0
#
# [168 rows x 2 columns]

# %%
# dep

y = data['Admitted']

# %%
y
# Out:
# 0      0.0
# 1      NaN
# 2      NaN
# 3      0.0
# 4      0.0
#       ...
# 163    NaN
# 164    NaN
# 165    0.0
# 166    0.0
# 167    0.0
# Name: Admitted, Length: 168, dtype: float64

# %%
x1 = data['SAT']   # indep

# %%
x1
# Out:
# 0      1363
# 1      1792
# 2      1954
# 3      1653
# 4      1593
#        ...
# 163    1722
# 164    1750
# 165    1555
# 166    1524
# 167    1461
# Name: SAT, Length: 168, dtype: int64

# %%
plt.scatter(x1,y,color='g')
plt.xlabel('SAT')
plt.ylabel('Admitted')
plt.show()

# %%
x = sm.add_constant(x1)

# %%
x
# Out:
#      const   SAT
# 0      1.0  1363
# 1      1.0  1792
# 2      1.0  1954
# 3      1.0  1653
# 4      1.0  1593
# ..     ...   ...
# 163    1.0  1722
# 164    1.0  1750
# 165    1.0  1555
# 166    1.0  1524
# 167    1.0  1461
#
# [168 rows x 2 columns]

# %%
reg_lin = sm.OLS(y,x)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 reg_lin = sm.OLS(y,x)
#
# NameError: name 'sm' is not defined
