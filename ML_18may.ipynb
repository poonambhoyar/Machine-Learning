# %%
import numpy as np
import pandas as pd

# %% [markdown]
# Data Frame

# %%
df = pd.DataFrame(np.random.randn(5,4),columns=['W','X','Y','Z'])

# %%
df
# Out:
#           W         X         Y         Z
# 0 -1.128595 -1.737227 -0.242487  0.851138
# 1 -1.702400 -0.149407 -2.226871 -1.306226
# 2 -0.942597  1.718965 -1.069582  1.176526
# 3 -3.164213 -0.153966 -0.322251  0.638019
# 4  0.267006  0.528366 -0.845436 -1.257159

# %%
df['W']
# Out:
# 0   -1.128595
# 1   -1.702400
# 2   -0.942597
# 3   -3.164213
# 4    0.267006
# Name: W, dtype: float64

# %%
df.W
# Out:
# 0   -1.128595
# 1   -1.702400
# 2   -0.942597
# 3   -3.164213
# 4    0.267006
# Name: W, dtype: float64

# %%
type(df['W'])
# Out:
# pandas.core.series.Series

# %%
df[['W','Z']]
# Out:
#           W         Z
# 0 -1.128595  0.851138
# 1 -1.702400 -1.306226
# 2 -0.942597  1.176526
# 3 -3.164213  0.638019
# 4  0.267006 -1.257159

# %%
type(df[['W','Z']])
# Out:
# pandas.core.frame.DataFrame

# %%
df['new'] = df['W'] + df['Z']

# %%
df
# Out:
#           W         X         Y         Z       new
# 0 -1.128595 -1.737227 -0.242487  0.851138 -0.277457
# 1 -1.702400 -0.149407 -2.226871 -1.306226 -3.008626
# 2 -0.942597  1.718965 -1.069582  1.176526  0.233929
# 3 -3.164213 -0.153966 -0.322251  0.638019 -2.526194
# 4  0.267006  0.528366 -0.845436 -1.257159 -0.990153

# %%
df['raj'] = [1,2,3,4,5]

# %%
df
# Out:
#           W         X         Y         Z       new  raj
# 0 -1.128595 -1.737227 -0.242487  0.851138 -0.277457    1
# 1 -1.702400 -0.149407 -2.226871 -1.306226 -3.008626    2
# 2 -0.942597  1.718965 -1.069582  1.176526  0.233929    3
# 3 -3.164213 -0.153966 -0.322251  0.638019 -2.526194    4
# 4  0.267006  0.528366 -0.845436 -1.257159 -0.990153    5

# %%
df.drop('raj',axis=1)   # for columns axis = 0 for rows
# Out:
#           W         X         Y         Z       new
# 0 -1.128595 -1.737227 -0.242487  0.851138 -0.277457
# 1 -1.702400 -0.149407 -2.226871 -1.306226 -3.008626
# 2 -0.942597  1.718965 -1.069582  1.176526  0.233929
# 3 -3.164213 -0.153966 -0.322251  0.638019 -2.526194
# 4  0.267006  0.528366 -0.845436 -1.257159 -0.990153

# %%
df
# Out:
#           W         X         Y         Z       new  raj
# 0 -1.128595 -1.737227 -0.242487  0.851138 -0.277457    1
# 1 -1.702400 -0.149407 -2.226871 -1.306226 -3.008626    2
# 2 -0.942597  1.718965 -1.069582  1.176526  0.233929    3
# 3 -3.164213 -0.153966 -0.322251  0.638019 -2.526194    4
# 4  0.267006  0.528366 -0.845436 -1.257159 -0.990153    5

# %%
df.drop('raj',axis=1,inplace=True)

# %%
df
# Out:
#           W         X         Y         Z       new
# 0 -1.128595 -1.737227 -0.242487  0.851138 -0.277457
# 1 -1.702400 -0.149407 -2.226871 -1.306226 -3.008626
# 2 -0.942597  1.718965 -1.069582  1.176526  0.233929
# 3 -3.164213 -0.153966 -0.322251  0.638019 -2.526194
# 4  0.267006  0.528366 -0.845436 -1.257159 -0.990153

# %%
df
# Out:
#           W         X         Y         Z       new
# 0 -1.128595 -1.737227 -0.242487  0.851138 -0.277457
# 1 -1.702400 -0.149407 -2.226871 -1.306226 -3.008626
# 2 -0.942597  1.718965 -1.069582  1.176526  0.233929
# 3 -3.164213 -0.153966 -0.322251  0.638019 -2.526194
# 4  0.267006  0.528366 -0.845436 -1.257159 -0.990153

# %%
df.drop('new',axis=1,inplace=True)

# %%
df
# Out:
#           W         X         Y         Z
# 0 -1.128595 -1.737227 -0.242487  0.851138
# 1 -1.702400 -0.149407 -2.226871 -1.306226
# 2 -0.942597  1.718965 -1.069582  1.176526
# 3 -3.164213 -0.153966 -0.322251  0.638019
# 4  0.267006  0.528366 -0.845436 -1.257159

# %%
df.drop(3,axis=0)
# Out:
#           W         X         Y         Z
# 0 -1.128595 -1.737227 -0.242487  0.851138
# 1 -1.702400 -0.149407 -2.226871 -1.306226
# 2 -0.942597  1.718965 -1.069582  1.176526
# 4  0.267006  0.528366 -0.845436 -1.257159

# %%
df.drop(3,axis=0,inplace=True)

# %%
df
# Out:
#           W         X         Y         Z
# 0 -1.128595 -1.737227 -0.242487  0.851138
# 1 -1.702400 -0.149407 -2.226871 -1.306226
# 2 -0.942597  1.718965 -1.069582  1.176526
# 4  0.267006  0.528366 -0.845436 -1.257159

# %%
df.shape
# Out:
# (4, 4)

# %%
df.iloc[2]   # for accessing rows
# Out:
# W   -0.942597
# X    1.718965
# Y   -1.069582
# Z    1.176526
# Name: 2, dtype: float64

# %%
df.iloc[3]
# Out:
# W    0.267006
# X    0.528366
# Y   -0.845436
# Z   -1.257159
# Name: 4, dtype: float64

# %%
df = pd.DataFrame(np.random.randn(5,4),columns=['W','X','Y','Z'])

# %%
df
# Out:
#           W         X         Y         Z
# 0  0.223950  0.337135 -0.883820 -0.276216
# 1 -0.824398 -2.441078  3.954110 -0.925281
# 2  1.314355  0.956074  1.746942 -1.024657
# 3  0.198138  1.402927 -1.174590 -0.317324
# 4 -2.055257 -0.341586  0.627662  0.071738

# %%
df.iloc[0:,2:]
# Out:
#           Y         Z
# 0 -0.883820 -0.276216
# 1  3.954110 -0.925281
# 2  1.746942 -1.024657
# 3 -1.174590 -0.317324
# 4  0.627662  0.071738

# %%
df.iloc[2:,2:]
# Out:
#           Y         Z
# 2  1.746942 -1.024657
# 3 -1.174590 -0.317324
# 4  0.627662  0.071738

# %%
df.iloc[0:3,1:]
# Out:
#           X         Y         Z
# 0  0.337135 -0.883820 -0.276216
# 1 -2.441078  3.954110 -0.925281
# 2  0.956074  1.746942 -1.024657
